# %%
# conditional_statments

# %%
age = 29
if age>18:
    print('u can vote')
# Out:
# u can vote

# %%
# else bock
age = 17
if age>18:
    print('u can vote')
else:
    print('u r a childu')
# Out:
# u r a childu

# %%
# elif
age = 20
if age<13:
    print('u are a kid')
elif age<18:
    print('u are a teenager') 
else:
        print('u r a adult')
# Out:
# u r a adult

# %%
# nested condition statements
# even n odd 
num = int(input('enter the number only'))
if num%2==0:
    print(num,'is a even numebr')
else:
    print(num,'numebr is odd')
# Out:
# 56 is a even numebr

# %%
# prsctical examplies
# find if a year is leap year
year = int(input('enter year only'))
if year%4==0:
     if year%100==0:
        if year%400==0:
            print('the year is leap year')
        else:
            print('the year is not a leapyear')
    else:
        print('the year is not a leapyear')
else:
        print('the year is not a leapyear')
# Out:
#   File <string>:10
#     else:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
# simple calculator
num = float(input('enter any integer'))
num1 = float(input('enter any integer'))
oparation = input('enter +,-,*/')

if oparation=='+':
    result = num+num1
elif oparation=='-':
    result = num-num1
elif oparation=='*':
    result= num*num1
elif oparation=='/':
    result = num/num1

else:
    print('younhave entered wrong oparation')
print(result)
# Out:
# 0.0

# %%
print('w')
# Out:
# w

# %%
# simple timepass
age = int(input('enter your age in numbers only eg 25'))
is_student = input('are you a student(yes/no)')

if age<=10 and is_student.lower=='yes':
    prin('your fee is free')
if age>=18 or is_student.lower=='yes':
    print('your discouted fee  is  chocholate')
# Out:
# your discouted fee  is  chocholate

# %%
for i in range(4):
    print(i*2)
# Out:
# 0
# 2
# 4
# 6

# %%
for i  in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10,5,-2):
    print(i-1)
# Out:
# 9
# 7
# 5

# %%
# string
srt = 'sanjay'
for i in srt:
    print(i)
# Out:
# s
# a
# n
# j
# a
# y

# %%
#while loop
tanetane = 0

while tanetane<5:
    print('tanetane')
    tanetane = tanetane+1
# Out:
# tanetane
# tanetane
# tanetane
# tanetane
# tanetane

# %%
# loop control statemnts
# break statements 
# break exits the loop premeturly
for i in range (10):
    if i==5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# continue
#contine skipps the current ittration and moves to next one
for i  in range(10):
    if i%2==0:
        continue
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#pass
# it is a ntg function
for i in range (5):
    if i==2:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# nested loop
for i in range(3):
    for j in range(i):
        print(i,j)
# Out:
# 1 0
# 2 0
# 2 1

# %%
# calculate the sum of first N natural number 
n = 10
sum = 0
count = 1

while count<=10:
    sum = sum+count
    count = count+1
print('the sum of first N natural number',sum)
# Out:
# the sum of first N natural number 55
